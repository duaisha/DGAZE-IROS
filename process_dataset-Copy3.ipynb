# %%
import pandas as pd
import numpy as np
import cv2
import os
from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2
import matplotlib.pyplot as plt

# %%
def detect_face(img, n):
    
    # initialize dlib's face detector (HOG-based) and then create
    # the facial landmark predictor
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("shape_predictor.dat")
    
    # load the input image, resize it, and convert it to grayscale
    #image = cv2.imread(img)
    image = img
#     image = imutils.resize(image, width=500)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # detect faces in the grayscale image
    rects = detector(gray, 1)
    
    # loop over the face detections
    for (i, rect) in enumerate(rects):
        # determine the facial landmarks for the face region, then
        # convert the facial landmark (x, y)-coordinates to a NumPy
        # array
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)

        # convert dlib's rectangle to a OpenCV-style bounding box
        # [i.e., (x, y, w, h)], then draw the face bounding box
        (x, y, w, h) = face_utils.rect_to_bb(rect)
#         cv2.rectangle(image, (x-n, y-n), (x + w+n, y + h+n), (255, 255, 255), 6)

#         # show the face number
# #         cv2.putText(image, "Face #{}".format(i + 1), (x - 10, y - 10),
# #             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#         # loop over the (x, y)-coordinates for the facial landmarks
#         # and draw them on the image
#         for (x, y) in shape:
#             cv2.circle(image, (x, y), 4, (255, 255, 255), -1)
            
        
#         plt.imshow(image)
#         plt.show()
        return x,y,w,h

# %%
def count_frames(video):
    count = 0
    vid = cv2.VideoCapture(video)    
    while(True):
        ret, frame = vid.read()
        if(ret == False):
            break
        count += 1
        
    return count

# %%
def callibrate_corresponding_videos(video1, video2, video3, textfile, output_vid1, output_vid2, output_vid3, 
                                    out_textfile, n1):
    
    print("############################################################3")
    print("sample_" +str(n1))
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    
    if(n1>=10):
        file1 = pd.read_csv(textfile, header = None).values
        print(textfile,file1.shape)
    else:
        file1 = np.load(textfile)
        print(textfile,file1.shape)
    
    arr = [];
    
    #################################################################################################
    out1 = cv2.VideoWriter(output_vid1, fourcc, 25, (1440,1080)) ### driver
    out2 = cv2.VideoWriter(output_vid2, fourcc, 25, (1440,1080)) ### road
    out3 = cv2.VideoWriter(output_vid3, fourcc, 25, (1920, 1080)) ### original
    
    #################################################################################################
    cap1 = cv2.VideoCapture(video1)###### driver ###################
    frame_count1 = count_frames(video1)
    
    cap2 = cv2.VideoCapture(video2)###### road ####################
    frame_count2 = count_frames(video2)
    
    cap3 = cv2.VideoCapture(video3)###### Original ####################
    frame_count3 = count_frames(video3)
    
    #print(frame_count1, frame_count2, frame_count3)

    #################################################################################################
    i = 0; count = 0; flag =0

    if(frame_count2 == frame_count3):
        flag =1
        n = frame_count2
        first = frame_count2
        second = frame_count3

    elif(frame_count3 < frame_count2):
        n = frame_count2
        first = frame_count2
        second = frame_count3

    elif(frame_count3 > frame_count2):
        n = frame_count3
        first = frame_count3
        second = frame_count2

    diff = first - second
    if(diff != 0):
        drop = np.round(first/diff)
        print(n, drop, first, second, diff)
    k =0
    #print(file1)
    while(i < n):
        if(flag == 0):
            if(diff != 0 and i%drop == 0 ):
               # print(i)
                if(frame_count2 > frame_count3):
                    ret2, frame2 = cap2.read()
                    ret1, frame1 = cap1.read()

                else:
                    ret3, frame3 = cap3.read()
                   # print(i)
                    k +=1
            else:
                count += 1
               # print(k)
                ret1, frame1 = cap1.read()
                ret2, frame2 = cap2.read()
                ret3, frame3 = cap3.read()
                if(ret2 == False or ret3 == False):
                    break
                arr.append(file1[k])
                k +=1

                #print(frame1.shape, frame2.shape, frame3.shape)
              #  frame2 = cv2.resize(frame2, (692, 460))
              #  print(frame1.shape, frame2.shape)
                #print(ret1, ret2)
    #             if(ret2 == False or ret3 == False):
    #                 break
             #   frame3 = np.concatenate((frame1, frame2), axis =1)
                out1.write(frame1)
                out2.write(frame2)
                out3.write(frame3)

            i += 1
            
        elif(flag ==1):
            count += 1
            ret1, frame1 = cap1.read()
            ret2, frame2 = cap2.read()
            ret3, frame3 = cap3.read()
            if(ret2 == False or ret3 == False):
                break
            arr.append(file1[k])
            k +=1

            out1.write(frame1)
            out2.write(frame2)
            out3.write(frame3)

            i += 1
        
    print(first, second, count, np.array(arr).shape)
    
    arr = np.array(arr)
    np.save(out_textfile, arr)
        
    out1.release(); out2.release(); out3.release()
    cap1.release(); cap2.release(); cap3.release()

# %%
def call_callibrate_corresponding_videos(ur):

    directory1 = "dataset_samples_callibrated/user"+str(ur)
    if not os.path.exists(directory1):
        os.makedirs(directory1)
        
    directory2 = "dataset_samples_callibrated/user"+str(ur)+"/driver_view"
    if not os.path.exists(directory2):
        os.makedirs(directory2)
        
    directory3 = "dataset_samples_callibrated/user"+str(ur)+"/road_view"
    if not os.path.exists(directory3):
        os.makedirs(directory3)
        
    directory4 = "dataset_samples_callibrated/user"+str(ur)+"/original_road_view"
    if not os.path.exists(directory4):
        os.makedirs(directory4)
        
    for i in range(0,112):
  
        video1 = "dataset_samples/user"+str(ur)+"/driver_view/sample"+str(i+1)+".avi"            
        video2 = "dataset_samples/user"+str(ur)+"/road_view/sample"+str(i+1)+".avi"
        video3 = "original_samples2/trip"+str(i+1)+"_out_hist.avi"

        if(i+1 < 10):
            textfile = "original_samples2/trip"+str(i+1)+"_out.npy"
        else:
            textfile = "original_samples2/trip"+str(i+1)+"_out.txt"


        out_video1 = directory2 + "/sample_"+str(i+1)+".avi"
        out_video2 = directory3 + "/sample_"+str(i+1)+".avi"
        out_video3 = directory4 + "/sample_"+str(i+1)+".avi"
        out_textfile = directory4 + "/sample_"+str(i+1)+".npy"

        callibrate_corresponding_videos(video1, video2, video3, textfile, out_video1, out_video2, out_video3, out_textfile, i+1)

# %%
# call_callibrate_corresponding_videos(2)

# %%
call_callibrate_corresponding_videos(22)
# Out:
# ############################################################3
# sample_1
# original_samples2/trip1_out.npy (100, 2)
# 111 10.0 111 100 11
# 111 100 99 (99, 2)
# ############################################################3
# sample_2
# original_samples2/trip2_out.npy (100, 2)
# 115 8.0 115 100 15
# 115 100 100 (100, 2)
# ############################################################3
# sample_3
# original_samples2/trip3_out.npy (100, 2)
# 101 101.0 101 100 1
# 101 100 100 (100, 2)
# ############################################################3
# sample_4
# original_samples2/trip4_out.npy (100, 2)
# 100 4.0 100 76 24
# 100 76 75 (75, 2)
# ############################################################3
# sample_5
# original_samples2/trip5_out.npy (100, 2)
# 124 5.0 124 100 24
# 124 100 99 (99, 2)
# ############################################################3
# sample_6
# original_samples2/trip6_out.npy (100, 2)
# 114 8.0 114 100 14
# 114 100 99 (99, 2)
# ############################################################3
# sample_7
# original_samples2/trip7_out.npy (100, 2)
# 109 12.0 109 100 9
# 109 100 99 (99, 2)
# ############################################################3
# sample_8
# original_samples2/trip8_out.npy (100, 2)
# 114 8.0 114 100 14
# 114 100 99 (99, 2)
# ############################################################3
# sample_9
# original_samples2/trip9_out.npy (100, 2)
# 116 7.0 116 100 16
# 116 100 99 (99, 2)
# ############################################################3
# sample_10
# original_samples2/trip10_out.txt (64, 5)
# 88 4.0 88 64 24
# 88 64 65 (64, 5)
# ############################################################3
# sample_11
# original_samples2/trip11_out.txt (112, 5)
# 153 4.0 153 112 41
# 153 112 113 (112, 5)
# ############################################################3
# sample_12
# original_samples2/trip12_out.txt (86, 5)
# 121 3.0 121 86 35
# 121 86 80 (80, 5)
# ############################################################3
# sample_13
# original_samples2/trip13_out.txt (89, 5)
# 129 3.0 129 89 40
# 129 89 86 (86, 5)
# ############################################################3
# sample_14
# original_samples2/trip14_out.txt (77, 5)
# 112 3.0 112 77 35
# 112 77 74 (74, 5)
# ############################################################3
# sample_15
# original_samples2/trip15_out.txt (97, 5)
# 134 4.0 134 97 37
# 134 97 98 (97, 5)
# ############################################################3
# sample_16
# original_samples2/trip16_out.txt (80, 5)
# 111 4.0 111 80 31
# 111 80 81 (80, 5)
# ############################################################3
# sample_17
# original_samples2/trip17_out.txt (70, 5)
# 103 3.0 103 70 33
# 103 70 68 (68, 5)
# ############################################################3
# sample_18
# original_samples2/trip18_out.txt (86, 5)
# 121 3.0 121 86 35
# 121 86 80 (80, 5)
# ############################################################3
# sample_19
# original_samples2/trip19_out.txt (49, 5)
# 80 3.0 80 49 31
# 80 49 50 (49, 5)
# ############################################################3
# sample_20
# original_samples2/trip20_out.txt (147, 5)
# 195 4.0 195 147 48
# 195 147 146 (146, 5)
# ############################################################3
# sample_21
# original_samples2/trip21_out.txt (133, 5)
# 179 4.0 179 133 46
# 179 133 134 (133, 5)
# ############################################################3
# sample_22
# original_samples2/trip22_out.txt (115, 5)
# 155 4.0 155 115 40
# 155 115 116 (115, 5)
# ############################################################3
# sample_23
# original_samples2/trip23_out.txt (80, 5)
# 119 3.0 119 80 39
# 119 80 79 (79, 5)
# ############################################################3
# sample_24
# original_samples2/trip24_out.txt (133, 5)
# 180 4.0 180 133 47
# 180 133 134 (133, 5)
# ############################################################3
# sample_25
# original_samples2/trip25_out.txt (138, 5)
# 180 4.0 180 138 42
# 180 138 135 (135, 5)
# ############################################################3
# sample_26
# original_samples2/trip26_out.txt (141, 5)
# 186 4.0 186 141 45
# 186 141 139 (139, 5)
# ############################################################3
# sample_27
# original_samples2/trip27_out.txt (149, 5)
# 193 4.0 193 149 44
# 193 149 144 (144, 5)
# ############################################################3
# sample_28
# original_samples2/trip28_out.txt (91, 5)
# 123 4.0 123 91 32
# 123 91 92 (91, 5)
# ############################################################3
# sample_29
# original_samples2/trip29_out.txt (114, 5)
# 150 4.0 150 114 36
# 150 114 112 (112, 5)
# ############################################################3
# sample_30
# original_samples2/trip30_out.txt (76, 5)
# 112 3.0 112 76 36
# 112 76 74 (74, 5)
# ############################################################3
# sample_31
# original_samples2/trip31_out.txt (63, 5)
# 94 3.0 94 63 31
# 94 63 62 (62, 5)
# ############################################################3
# sample_32
# original_samples2/trip32_out.txt (75, 5)
# 110 3.0 110 75 35
# 110 75 73 (73, 5)
# ############################################################3
# sample_33
# original_samples2/trip33_out.txt (91, 5)
# 128 3.0 128 91 37
# 128 91 85 (85, 5)
# ############################################################3
# sample_34
# original_samples2/trip34_out.txt (129, 5)
# 177 4.0 177 129 48
# 177 129 130 (129, 5)
# ############################################################3
# sample_35
# original_samples2/trip35_out.txt (107, 5)
# 149 4.0 149 107 42
# 149 107 108 (107, 5)
# ############################################################3
# sample_36
# original_samples2/trip36_out.txt (125, 5)
# 169 4.0 169 125 44
# 169 125 126 (125, 5)
# ############################################################3
# sample_37
# original_samples2/trip37_out.txt (94, 5)
# 134 3.0 134 94 40
# 134 94 89 (89, 5)
# ############################################################3
# sample_38
# original_samples2/trip38_out.txt (165, 5)
# 215 4.0 215 165 50
# 215 165 161 (161, 5)
# ############################################################3
# sample_39
# original_samples2/trip39_out.txt (140, 5)
# 185 4.0 185 140 45
# 185 140 138 (138, 5)
# ############################################################3
# sample_40
# original_samples2/trip40_out.txt (122, 5)
# 167 4.0 167 122 45
# 167 122 123 (122, 5)
# ############################################################3
# sample_41
# original_samples2/trip41_out.txt (155, 5)
# 201 4.0 201 155 46
# 201 155 150 (150, 5)
# ############################################################3
# sample_42
# original_samples2/trip42_out.txt (160, 5)
# 212 4.0 212 160 52
# 212 160 159 (159, 5)
# ############################################################3
# sample_43
# original_samples2/trip43_out.txt (70, 5)
# 102 3.0 102 70 32
# 102 70 68 (68, 5)
# ############################################################3
# sample_44
# original_samples2/trip44_out.txt (137, 5)
# 183 4.0 183 137 46
# 183 137 137 (137, 5)
# ############################################################3
# sample_45
# original_samples2/trip45_out.txt (104, 5)
# 142 4.0 142 104 38
# 142 104 105 (104, 5)
# ############################################################3
# sample_46
# original_samples2/trip46_out.txt (86, 5)
# 115 4.0 115 86 29
# 115 86 86 (86, 5)
# ############################################################3
# sample_47
# original_samples2/trip47_out.txt (104, 5)
# 142 4.0 142 104 38
# 142 104 105 (104, 5)
# ############################################################3
# sample_48
# original_samples2/trip48_out.txt (82, 5)
# 119 3.0 119 82 37
# 119 82 79 (79, 5)
# ############################################################3
# sample_49
# original_samples2/trip49_out.txt (153, 5)
# 196 5.0 196 153 43
# 196 153 154 (153, 5)
# ############################################################3
# sample_50
# original_samples2/trip50_out.txt (100, 5)
# 136 4.0 136 100 36
# 136 100 101 (100, 5)
# ############################################################3
# sample_51
# original_samples2/trip51_out.txt (112, 5)
# 154 4.0 154 112 42
# 154 112 113 (112, 5)
# ############################################################3
# sample_52
# original_samples2/trip52_out.txt (205, 5)
# 258 5.0 258 205 53
# 258 205 206 (205, 5)
# ############################################################3
# sample_53
# original_samples2/trip53_out.txt (103, 5)
# 140 4.0 140 103 37
# 140 103 104 (103, 5)
# ############################################################3
# sample_54
# original_samples2/trip54_out.txt (123, 5)
# 167 4.0 167 123 44
# 167 123 124 (123, 5)
# ############################################################3
# sample_55
# original_samples2/trip55_out.txt (92, 5)
# 130 3.0 130 92 38
# 130 92 86 (86, 5)
# ############################################################3
# sample_56
# original_samples2/trip56_out.txt (121, 5)
# 163 4.0 163 121 42
# 163 121 122 (121, 5)
# ############################################################3
# sample_57
# original_samples2/trip57_out.txt (42, 5)
# 70 2.0 70 42 28
# 70 42 35 (35, 5)
# ############################################################3
# sample_58
# original_samples2/trip58_out.txt (118, 5)
# 160 4.0 160 118 42
# 160 118 119 (118, 5)
# ############################################################3
# sample_59
# original_samples2/trip59_out.txt (64, 5)
# 97 3.0 97 64 33
# 97 64 64 (64, 5)
# ############################################################3
# sample_60
# original_samples2/trip60_out.txt (68, 5)
# 103 3.0 103 68 35
# 103 68 68 (68, 5)
# ############################################################3
# sample_61
# original_samples2/trip61_out.txt (45, 5)
# 72 3.0 72 45 27
# 72 45 46 (45, 5)
# ############################################################3
# sample_62
# original_samples2/trip62_out.txt (114, 5)
# 156 4.0 156 114 42
# 156 114 115 (114, 5)
# ############################################################3
# sample_63
# original_samples2/trip63_out.txt (87, 5)
# 122 3.0 122 87 35
# 122 87 81 (81, 5)
# ############################################################3
# sample_64
# original_samples2/trip64_out.txt (48, 5)
# 81 2.0 81 48 33
# 81 48 40 (40, 5)
# ############################################################3
# sample_65
# original_samples2/trip65_out.txt (298, 5)
# 367 5.0 367 298 69
# 367 298 293 (293, 5)
# ############################################################3
# sample_66
# original_samples2/trip66_out.txt (82, 5)
# 118 3.0 118 82 36
# 118 82 78 (78, 5)
# ############################################################3
# sample_67
# original_samples2/trip67_out.txt (108, 5)
# 151 4.0 151 108 43
# 151 108 109 (108, 5)
# ############################################################3
# sample_68
# original_samples2/trip68_out.txt (60, 5)
# 91 3.0 91 60 31
# 91 60 60 (60, 5)
# ############################################################3
# sample_69
# original_samples2/trip69_out.txt (124, 5)
# 166 4.0 166 124 42
# 166 124 124 (124, 5)
# ############################################################3
# sample_70
# original_samples2/trip70_out.txt (103, 5)
# 141 4.0 141 103 38
# 141 103 104 (103, 5)
# ############################################################3
# sample_71
# original_samples2/trip71_out.txt (134, 5)
# 181 4.0 181 134 47
# 181 134 135 (134, 5)
# ############################################################3
# sample_72
# original_samples2/trip72_out.txt (164, 5)
# 209 5.0 209 164 45
# 209 164 165 (164, 5)
# ############################################################3
# sample_73
# original_samples2/trip73_out.txt (207, 5)
# 263 5.0 263 207 56
# 263 207 208 (207, 5)
# ############################################################3
# sample_74
# original_samples2/trip74_out.txt (93, 5)
# 133 3.0 133 93 40
# 133 93 88 (88, 5)
# ############################################################3
# sample_75
# original_samples2/trip75_out.txt (80, 5)
# 112 4.0 112 80 32
# 112 80 81 (80, 5)
# ############################################################3
# sample_76
# original_samples2/trip76_out.txt (59, 5)
# 93 3.0 93 59 34
# 93 59 60 (59, 5)
# ############################################################3
# sample_77
# original_samples2/trip77_out.txt (88, 5)
# 127 3.0 127 88 39
# 127 88 84 (84, 5)
# ############################################################3
# sample_78
# original_samples2/trip78_out.txt (133, 5)
# 176 4.0 176 133 43
# 176 133 132 (132, 5)
# ############################################################3
# sample_79
# original_samples2/trip79_out.txt (81, 5)
# 117 3.0 117 81 36
# 117 81 78 (78, 5)
# ############################################################3
# sample_80
# original_samples2/trip80_out.txt (113, 5)
# 144 5.0 144 113 31
# 144 113 114 (113, 5)
# ############################################################3
# sample_81
# original_samples2/trip81_out.txt (115, 5)
# 155 4.0 155 115 40
# 155 115 116 (115, 5)
# ############################################################3
# sample_82
# original_samples2/trip82_out.txt (80, 5)
# 108 4.0 108 80 28
# 108 80 81 (80, 5)
# ############################################################3
# sample_83
# original_samples2/trip83_out.txt (138, 5)
# 138 2.0 138 48 90
# 138 48 49 (48, 5)
# ############################################################3
# sample_84
# original_samples2/trip84_out.txt (91, 5)
# 124 4.0 124 91 33
# 124 91 92 (91, 5)
# ############################################################3
# sample_85
# original_samples2/trip85_out.txt (180, 5)
# 218 6.0 218 180 38
# 218 180 181 (180, 5)
# ############################################################3
# sample_86
# original_samples2/trip86_out.txt (146, 5)
# 187 5.0 187 146 41
# 187 146 147 (146, 5)
# ############################################################3
# sample_87
# original_samples2/trip87_out.txt (108, 5)
# 144 4.0 144 108 36
# 144 108 108 (108, 5)
# ############################################################3
# sample_88
# original_samples2/trip88_out.txt (58, 5)
# 86 3.0 86 58 28
# 86 58 57 (57, 5)
# ############################################################3
# sample_89
# original_samples2/trip89_out.txt (190, 5)
# 231 6.0 231 190 41
# 231 190 191 (190, 5)
# ############################################################3
# sample_90
# original_samples2/trip90_out.txt (119, 5)
# 155 4.0 155 119 36
# 155 119 116 (116, 5)
# ############################################################3
# sample_91
# original_samples2/trip91_out.txt (165, 5)
# 204 5.0 204 165 39
# 204 165 163 (163, 5)
# ############################################################3
# sample_92
# original_samples2/trip92_out.txt (143, 5)
# 177 5.0 177 143 34
# 177 143 141 (141, 5)
# ############################################################3
# sample_93
# original_samples2/trip93_out.txt (58, 5)
# 88 3.0 88 58 30
# 88 58 58 (58, 5)
# ############################################################3
# sample_94
# original_samples2/trip94_out.txt (109, 5)
# 141 4.0 141 109 32
# 141 109 105 (105, 5)
# ############################################################3
# sample_95
# original_samples2/trip95_out.txt (148, 5)
# 188 5.0 188 148 40
# 188 148 149 (148, 5)
# ############################################################3
# sample_96
# original_samples2/trip96_out.txt (134, 5)
# 170 5.0 170 134 36
# 170 134 135 (134, 5)
# ############################################################3
# sample_97
# original_samples2/trip97_out.txt (114, 5)
# 147 4.0 147 114 33
# 147 114 110 (110, 5)
# ############################################################3
# sample_98
# original_samples2/trip98_out.txt (163, 5)
# 197 6.0 197 163 34
# 197 163 164 (163, 5)
# ############################################################3
# sample_99
# original_samples2/trip99_out.txt (102, 5)
# 139 4.0 139 102 37
# 139 102 103 (102, 5)
# ############################################################3
# sample_100
# original_samples2/trip100_out.txt (130, 5)
# 172 4.0 172 130 42
# 172 130 129 (129, 5)
# ############################################################3
# sample_101
# original_samples2/trip101_out.txt (74, 5)
# 110 3.0 110 74 36
# 110 74 73 (73, 5)
# ############################################################3
# sample_102
# original_samples2/trip102_out.txt (93, 5)
# 134 3.0 134 93 41
# 134 93 89 (89, 5)
# ############################################################3
# sample_103
# original_samples2/trip103_out.txt (62, 5)
# 88 3.0 88 62 26
# 88 62 58 (58, 5)
# ############################################################3
# sample_104
# original_samples2/trip104_out.txt (115, 5)
# 149 4.0 149 115 34
# 149 115 111 (111, 5)
# ############################################################3
# sample_105
# original_samples2/trip105_out.txt (184, 5)
# 224 6.0 224 184 40
# 224 184 185 (184, 5)
# ############################################################3
# sample_106
# original_samples2/trip106_out.txt (182, 5)
# 230 5.0 230 182 48
# 230 182 183 (182, 5)
# ############################################################3
# sample_107
# original_samples2/trip107_out.txt (126, 5)
# 167 4.0 167 126 41
# 167 126 125 (125, 5)
# ############################################################3
# sample_108
# original_samples2/trip108_out.txt (140, 5)
# 175 5.0 175 140 35
# 175 140 140 (140, 5)
# ############################################################3
# sample_109
# original_samples2/trip109_out.txt (202, 5)
# 243 6.0 243 202 41
# 243 202 202 (202, 5)
# ############################################################3
# sample_110
# original_samples2/trip110_out.txt (216, 5)
# 261 6.0 261 216 45
# 261 216 217 (216, 5)
# ############################################################3
# sample_111
# original_samples2/trip111_out.txt (179, 5)
# 216 6.0 216 179 37
# 216 179 180 (179, 5)
# ############################################################3
# sample_112
# original_samples2/trip112_out.txt (178, 5)
# 178 2.0 178 60 118
# 178 60 61 (60, 5)

# %%
ur = 18

for i in range(1):
    videofile = "dataset_samples_callibrated/user"+str(ur)+"/driver_view/sample_" +str(i+1)+".avi"
    vid  = cv2.VideoCapture(videofile)
    if(os.path.exists(videofile)):
        print('y')
    else:
        print('n')
    while(True):
        ret, frame = vid.read()
        if(ret == False):
            break
        n =100
        x,y,w,h = detect_face(frame, 100)
        x1 = x-n; y1= y-n
        if(x1 <=0):
            x1 =0
        if(y1 <= 0):
            y1 = 0
        cv2.rectangle(frame, (x1, y1), (x + w+n, y + h+n), (255, 255, 255), 6)
        frame1 = frame[ y1:y+h+n, x1:x+w+n]
        plt.imshow(frame)
        plt.show()
        break
# Out:
# y

# %%
def crop_driver_video(videofile, destination_video,destination_file, n):
    
    vid  = cv2.VideoCapture(videofile)
    i  =0; flag =0; arr = []
    if(os.path.exists(videofile)):
        
        while(True):
            temp = []
            ret, frame = vid.read()
            if(ret == False):
                flag =1
                break

            if(i ==0):
                x,y,w,h = detect_face(frame, n)
                x1 = x-n; y1= y-n
                if(x1 <=0):
                    x1 =0
                if(y1 <= 0):
                    y1 = 0
                
                fourcc = cv2.VideoWriter_fourcc(*'XVID')
                out = cv2.VideoWriter(destination_video,fourcc, 21, (x+w+n-x1,y+h+n-y1))

                

                #cv2.rectangle(frame, (x1, y1), (x + w+n, y + h+n), (255, 255, 255), 6)
        
            frame1 = frame[y1:y+h+n, x1:x+w+n]
            temp.append(y1)
            temp.append(y+h+n)
            temp.append(x1)
            temp.append(x+w+n)
            arr.append(temp)
            #print(frame1.shape)
            #print(frame.shape, frame1.shape)
            #print(i, w+2*n,h+2*n)
          #  cv2.rectangle(image, (x-n, y-n), (x + w+n, y + h+n), (255, 255, 255), 6)
            out.write(frame1)
            i +=1
        np.save(destination_file, np.array(arr))
        if(flag ==0):
            out.release()
            vid.release()
            
        else:
            print(i)

# %%
def call_crop_driver_video(ur):
    directory1 = "dataset_samples_callibrated/user"+str(ur)+"/driver_view_cropped2/"
    directory2 = "dataset_samples_callibrated/user"+str(ur)+"/explicit_face_points/"
    if not os.path.exists(directory1):
        os.makedirs(directory1)
    
    if not os.path.exists(directory2):
        os.makedirs(directory2)
        
    for i in range(96,112):
        print("user"+str(ur), "sample_" +str(i+1)+".avi")
        video_filename = "dataset_samples_callibrated/user"+str(ur)+"/driver_view/sample_" +str(i+1)+".avi"
        crop_driver_video(video_filename, directory1 +"sample_" + str(i+1)+".avi", directory2 +"sample_" + str(i+1)+"_face_points.npy",100)

# %%
call_crop_driver_video(20)
# Out:
# user20 sample_1.avi
# 100
# user20 sample_2.avi
# 100
# user20 sample_3.avi
# 99
# user20 sample_4.avi
# 100
# user20 sample_5.avi
# 99
# user20 sample_6.avi
# 99
# user20 sample_7.avi
# 99
# user20 sample_8.avi
# 99
# user20 sample_9.avi
# 100
# user20 sample_10.avi
# 62
# user20 sample_11.avi
# 112
# user20 sample_12.avi
# 86
# user20 sample_13.avi
# 84
# user20 sample_14.avi
# 77
# user20 sample_15.avi
# 91
# user20 sample_16.avi
# 78
# user20 sample_17.avi
# 68
# user20 sample_18.avi
# 86
# user20 sample_19.avi
# 49
# user20 sample_20.avi
# 144
# user20 sample_21.avi
# 132
# user20 sample_22.avi
# 115
# user20 sample_23.avi
# 78
# user20 sample_24.avi
# 133
# user20 sample_25.avi
# 136
# user20 sample_26.avi
# 137
# user20 sample_27.avi
# 144
# user20 sample_28.avi
# 91
# user20 sample_29.avi
# 114
# user20 sample_30.avi
# 72
# user20 sample_31.avi
# 62
# user20 sample_32.avi
# 72
# user20 sample_33.avi
# 90
# user20 sample_34.avi
# 124
# user20 sample_35.avi
# 105
# user20 sample_36.avi
# 124
# user20 sample_37.avi
# 94
# user20 sample_38.avi
# 165
# user20 sample_39.avi
# 135
# user20 sample_40.avi
# 119
# user20 sample_41.avi
# 154
# user20 sample_42.avi
# 158
# user20 sample_43.avi
# 70
# user20 sample_44.avi
# 137
# user20 sample_45.avi
# 102
# user20 sample_46.avi
# 86
# user20 sample_47.avi
# 104
# user20 sample_48.avi
# 82
# user20 sample_49.avi
# 150
# user20 sample_50.avi
# 100
# user20 sample_51.avi
# 96
# user20 sample_52.avi
# 201
# user20 sample_53.avi
# 101
# user20 sample_54.avi
# 120
# user20 sample_55.avi
# 92
# user20 sample_56.avi
# 121
# user20 sample_57.avi
# 35
# user20 sample_58.avi
# 118
# user20 sample_59.avi
# 62
# user20 sample_60.avi
# 67
# user20 sample_61.avi
# 45
# user20 sample_62.avi
# 111
# user20 sample_63.avi
# 87
# user20 sample_64.avi
# 48
# user20 sample_65.avi
# 298
# user20 sample_66.avi
# 82
# user20 sample_67.avi
# 108
# user20 sample_68.avi
# 60
# user20 sample_69.avi
# 120
# user20 sample_70.avi
# 102
# user20 sample_71.avi
# 132
# user20 sample_72.avi
# 159
# user20 sample_73.avi
# 204
# user20 sample_74.avi
# 91
# user20 sample_75.avi
# 77
# user20 sample_76.avi
# 59
# user20 sample_77.avi
# 88
# user20 sample_78.avi
# 133
# user20 sample_79.avi
# 81
# user20 sample_80.avi
# 110
# user20 sample_81.avi
# 114
# user20 sample_82.avi
# 80
# user20 sample_83.avi
# 138
# user20 sample_84.avi
# 91
# user20 sample_85.avi
# 178
# user20 sample_86.avi
# 141
# user20 sample_87.avi
# 108
# user20 sample_88.avi
# 58
# user20 sample_89.avi
# 175
# user20 sample_90.avi
# 119
# user20 sample_91.avi
# 165
# user20 sample_92.avi
# 138
# user20 sample_93.avi
# 56
# user20 sample_94.avi
# 109
# user20 sample_95.avi
# 148
# user20 sample_96.avi
# 133
# user20 sample_97.avi
# 114
# user20 sample_98.avi
# 163
# user20 sample_99.avi
# 102
# user20 sample_100.avi
# 111
# user20 sample_101.avi
# 34
# user20 sample_102.avi
# 43
# user20 sample_103.avi
# 31
# user20 sample_104.avi
# 83
# user20 sample_105.avi
# 137
# user20 sample_106.avi
# 176
# user20 sample_107.avi
# 124
# user20 sample_108.avi
# 140
# user20 sample_109.avi
# 196
# user20 sample_110.avi
# 210
# user20 sample_111.avi
# 179
# user20 sample_112.avi
# 0

# %%
call_crop_driver_video(24)
# Out:
# user24 sample_97.avi
# 114
# user24 sample_98.avi
# 163
# user24 sample_99.avi
# 99
# user24 sample_100.avi
# 129
# user24 sample_101.avi
# 74
# user24 sample_102.avi
# 93
# user24 sample_103.avi
# 60
# user24 sample_104.avi
# 115
# user24 sample_105.avi
# 184
# user24 sample_106.avi
# 182
# user24 sample_107.avi
# 126
# user24 sample_108.avi
# 140
# user24 sample_109.avi
# 201
# user24 sample_110.avi
# 215
# user24 sample_111.avi
# 177
# user24 sample_112.avi
# 85
