# %%
import pandas as pd
import numpy as np
import cv2
import os
from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2
import matplotlib.pyplot as plt

# %%
def detect_face(img, n):
    
    # initialize dlib's face detector (HOG-based) and then create
    # the facial landmark predictor
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("shape_predictor.dat")
    
    # load the input image, resize it, and convert it to grayscale
    #image = cv2.imread(img)
    image = img
#     image = imutils.resize(image, width=500)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # detect faces in the grayscale image
    rects = detector(gray, 1)
    
    # loop over the face detections
    for (i, rect) in enumerate(rects):
        # determine the facial landmarks for the face region, then
        # convert the facial landmark (x, y)-coordinates to a NumPy
        # array
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)

        # convert dlib's rectangle to a OpenCV-style bounding box
        # [i.e., (x, y, w, h)], then draw the face bounding box
        (x, y, w, h) = face_utils.rect_to_bb(rect)
#         cv2.rectangle(image, (x-n, y-n), (x + w+n, y + h+n), (255, 255, 255), 6)

#         # show the face number
# #         cv2.putText(image, "Face #{}".format(i + 1), (x - 10, y - 10),
# #             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#         # loop over the (x, y)-coordinates for the facial landmarks
#         # and draw them on the image
#         for (x, y) in shape:
#             cv2.circle(image, (x, y), 4, (255, 255, 255), -1)
            
        
#         plt.imshow(image)
#         plt.show()
        return x,y,w,h

# %%
def count_frames(video):
    count = 0
    vid = cv2.VideoCapture(video)    
    while(True):
        ret, frame = vid.read()
        if(ret == False):
            break
        count += 1
        
    return count

# %%
def callibrate_corresponding_videos(video1, video2, video3, textfile, output_vid1, output_vid2, output_vid3, 
                                    out_textfile, n1):
    
    print("############################################################3")
    print("sample_" +str(n1))
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    
    if(n1>=10):
        file1 = pd.read_csv(textfile, header = None).values
        print(textfile,file1.shape)
    else:
        file1 = np.load(textfile)
        print(textfile,file1.shape)
    
    arr = [];
    
    #################################################################################################
    out1 = cv2.VideoWriter(output_vid1, fourcc, 25, (1440,1080)) ### driver
    out2 = cv2.VideoWriter(output_vid2, fourcc, 25, (1440,1080)) ### road
    out3 = cv2.VideoWriter(output_vid3, fourcc, 25, (1920, 1080)) ### original
    
    #################################################################################################
    cap1 = cv2.VideoCapture(video1)###### driver ###################
    frame_count1 = count_frames(video1)
    
    cap2 = cv2.VideoCapture(video2)###### road ####################
    frame_count2 = count_frames(video2)
    
    cap3 = cv2.VideoCapture(video3)###### Original ####################
    frame_count3 = count_frames(video3)
    
    #print(frame_count1, frame_count2, frame_count3)

    #################################################################################################
    i = 0; count = 0; flag =0

    if(frame_count2 == frame_count3):
        flag =1
        n = frame_count2
        first = frame_count2
        second = frame_count3

    elif(frame_count3 < frame_count2):
        n = frame_count2
        first = frame_count2
        second = frame_count3

    elif(frame_count3 > frame_count2):
        n = frame_count3
        first = frame_count3
        second = frame_count2

    diff = first - second
    if(diff != 0):
        drop = np.round(first/diff)
        print(n, drop, first, second, diff)
    k =0
    #print(file1)
    while(i < n):
        if(flag == 0):
            if(diff != 0 and i%drop == 0 ):
               # print(i)
                if(frame_count2 > frame_count3):
                    ret2, frame2 = cap2.read()
                    ret1, frame1 = cap1.read()

                else:
                    ret3, frame3 = cap3.read()
                   # print(i)
                    k +=1
            else:
                count += 1
               # print(k)
                ret1, frame1 = cap1.read()
                ret2, frame2 = cap2.read()
                ret3, frame3 = cap3.read()
                if(ret2 == False or ret3 == False):
                    break
                arr.append(file1[k])
                k +=1

                #print(frame1.shape, frame2.shape, frame3.shape)
              #  frame2 = cv2.resize(frame2, (692, 460))
              #  print(frame1.shape, frame2.shape)
                #print(ret1, ret2)
    #             if(ret2 == False or ret3 == False):
    #                 break
             #   frame3 = np.concatenate((frame1, frame2), axis =1)
                out1.write(frame1)
                out2.write(frame2)
                out3.write(frame3)

            i += 1
            
        elif(flag ==1):
            count += 1
            ret1, frame1 = cap1.read()
            ret2, frame2 = cap2.read()
            ret3, frame3 = cap3.read()
            if(ret2 == False or ret3 == False):
                break
            arr.append(file1[k])
            k +=1

            out1.write(frame1)
            out2.write(frame2)
            out3.write(frame3)

            i += 1
        
    print(first, second, count, np.array(arr).shape)
    
    arr = np.array(arr)
    np.save(out_textfile, arr)
        
    out1.release(); out2.release(); out3.release()
    cap1.release(); cap2.release(); cap3.release()

# %%
def call_callibrate_corresponding_videos(ur):

    directory1 = "dataset_samples_callibrated/user"+str(ur)
    if not os.path.exists(directory1):
        os.makedirs(directory1)
        
    directory2 = "dataset_samples_callibrated/user"+str(ur)+"/driver_view"
    if not os.path.exists(directory2):
        os.makedirs(directory2)
        
    directory3 = "dataset_samples_callibrated/user"+str(ur)+"/road_view"
    if not os.path.exists(directory3):
        os.makedirs(directory3)
        
    directory4 = "dataset_samples_callibrated/user"+str(ur)+"/original_road_view"
    if not os.path.exists(directory4):
        os.makedirs(directory4)
        
    for i in range(0,112):
  
        video1 = "dataset_samples/user"+str(ur)+"/driver_view/sample"+str(i+1)+".avi"            
        video2 = "dataset_samples/user"+str(ur)+"/road_view/sample"+str(i+1)+".avi"
        video3 = "original_samples2/trip"+str(i+1)+"_out_hist.avi"

        if(i+1 < 10):
            textfile = "original_samples2/trip"+str(i+1)+"_out.npy"
        else:
            textfile = "original_samples2/trip"+str(i+1)+"_out.txt"


        out_video1 = directory2 + "/sample_"+str(i+1)+".avi"
        out_video2 = directory3 + "/sample_"+str(i+1)+".avi"
        out_video3 = directory4 + "/sample_"+str(i+1)+".avi"
        out_textfile = directory4 + "/sample_"+str(i+1)+".npy"

        callibrate_corresponding_videos(video1, video2, video3, textfile, out_video1, out_video2, out_video3, out_textfile, i+1)

# %%
# call_callibrate_corresponding_videos(2)

# %%
call_callibrate_corresponding_videos(21)
# Out:
# ############################################################3
# sample_1
# original_samples2/trip1_out.npy (100, 2)
# 100 3.0 100 71 29
# 100 71 66 (66, 2)
# ############################################################3
# sample_2
# original_samples2/trip2_out.npy (100, 2)
# 106 18.0 106 100 6
# 106 100 100 (100, 2)
# ############################################################3
# sample_3
# original_samples2/trip3_out.npy (100, 2)
# 100 50.0 100 98 2
# 100 98 98 (98, 2)
# ############################################################3
# sample_4
# original_samples2/trip4_out.npy (100, 2)
# 106 18.0 106 100 6
# 106 100 100 (100, 2)
# ############################################################3
# sample_5
# original_samples2/trip5_out.npy (100, 2)
# 100 20.0 100 95 5
# 100 95 95 (95, 2)
# ############################################################3
# sample_6
# original_samples2/trip6_out.npy (100, 2)
# 100 7.0 100 86 14
# 100 86 85 (85, 2)
# ############################################################3
# sample_7
# original_samples2/trip7_out.npy (100, 2)
# 100 6.0 100 83 17
# 100 83 83 (83, 2)
# ############################################################3
# sample_8
# original_samples2/trip8_out.npy (100, 2)
# 100 10.0 100 90 10
# 100 90 90 (90, 2)
# ############################################################3
# sample_9
# original_samples2/trip9_out.npy (100, 2)
# 100 8.0 100 87 13
# 100 87 87 (87, 2)
# ############################################################3
# sample_10
# original_samples2/trip10_out.txt (64, 5)
# 80 5.0 80 64 16
# 80 64 64 (64, 5)
# ############################################################3
# sample_11
# original_samples2/trip11_out.txt (112, 5)
# 112 2.0 112 63 49
# 112 63 56 (56, 5)
# ############################################################3
# sample_12
# original_samples2/trip12_out.txt (86, 5)
# 113 4.0 113 86 27
# 113 86 84 (84, 5)
# ############################################################3
# sample_13
# original_samples2/trip13_out.txt (89, 5)
# 89 22.0 89 85 4
# 89 85 84 (84, 5)
# ############################################################3
# sample_14
# original_samples2/trip14_out.txt (77, 5)
# 98 5.0 98 77 21
# 98 77 78 (77, 5)
# ############################################################3
# sample_15
# original_samples2/trip15_out.txt (97, 5)
# 97 6.0 97 80 17
# 97 80 80 (80, 5)
# ############################################################3
# sample_16
# original_samples2/trip16_out.txt (80, 5)
# 100 5.0 100 80 20
# 100 80 80 (80, 5)
# ############################################################3
# sample_17
# original_samples2/trip17_out.txt (70, 5)
# 72 36.0 72 70 2
# 72 70 70 (70, 5)
# ############################################################3
# sample_18
# original_samples2/trip18_out.txt (86, 5)
# 86 10.0 86 77 9
# 86 77 77 (77, 5)
# ############################################################3
# sample_19
# original_samples2/trip19_out.txt (49, 5)
# 88 2.0 88 49 39
# 88 49 44 (44, 5)
# ############################################################3
# sample_20
# original_samples2/trip20_out.txt (147, 5)
# 147 2.0 147 58 89
# 147 58 59 (58, 5)
# ############################################################3
# sample_21
# original_samples2/trip21_out.txt (133, 5)
# 133 66.0 133 131 2
# 133 131 130 (130, 5)
# ############################################################3
# sample_22
# original_samples2/trip22_out.txt (115, 5)
# 115 38.0 115 112 3
# 115 112 111 (111, 5)
# ############################################################3
# sample_23
# original_samples2/trip23_out.txt (80, 5)
# 118 3.0 118 80 38
# 118 80 78 (78, 5)
# ############################################################3
# sample_24
# original_samples2/trip24_out.txt (133, 5)
# 133 3.0 133 83 50
# 133 83 84 (83, 5)
# ############################################################3
# sample_25
# original_samples2/trip25_out.txt (138, 5)
# 138 46.0 138 135 3
# 138 135 135 (135, 5)
# ############################################################3
# sample_26
# original_samples2/trip26_out.txt (141, 5)
# 141 35.0 141 137 4
# 141 137 136 (136, 5)
# ############################################################3
# sample_27
# original_samples2/trip27_out.txt (149, 5)
# 149 9.0 149 132 17
# 149 132 132 (132, 5)
# ############################################################3
# sample_28
# original_samples2/trip28_out.txt (91, 5)
# 148 3.0 148 91 57
# 148 91 92 (91, 5)
# ############################################################3
# sample_29
# original_samples2/trip29_out.txt (114, 5)
# 114 8.0 114 99 15
# 114 99 99 (99, 5)
# ############################################################3
# sample_30
# original_samples2/trip30_out.txt (76, 5)
# 105 4.0 105 76 29
# 105 76 77 (76, 5)
# ############################################################3
# sample_31
# original_samples2/trip31_out.txt (63, 5)
# 80 5.0 80 63 17
# 80 63 64 (63, 5)
# ############################################################3
# sample_32
# original_samples2/trip32_out.txt (75, 5)
# 75 8.0 75 65 10
# 75 65 65 (65, 5)
# ############################################################3
# sample_33
# original_samples2/trip33_out.txt (91, 5)
# 91 5.0 91 73 18
# 91 73 72 (72, 5)
# ############################################################3
# sample_34
# original_samples2/trip34_out.txt (129, 5)
# 129 3.0 129 83 46
# 129 83 84 (83, 5)
# ############################################################3
# sample_35
# original_samples2/trip35_out.txt (107, 5)
# 111 28.0 111 107 4
# 111 107 107 (107, 5)
# ############################################################3
# sample_36
# original_samples2/trip36_out.txt (125, 5)
# 125 3.0 125 89 36
# 125 89 83 (83, 5)
# ############################################################3
# sample_37
# original_samples2/trip37_out.txt (94, 5)
# 102 13.0 102 94 8
# 102 94 94 (94, 5)
# ############################################################3
# sample_38
# original_samples2/trip38_out.txt (165, 5)
# 165 2.0 165 78 87
# 165 78 79 (78, 5)
# ############################################################3
# sample_39
# original_samples2/trip39_out.txt (140, 5)
# 140 9.0 140 124 16
# 140 124 124 (124, 5)
# ############################################################3
# sample_40
# original_samples2/trip40_out.txt (122, 5)
# 122 9.0 122 109 13
# 122 109 108 (108, 5)
# ############################################################3
# sample_41
# original_samples2/trip41_out.txt (155, 5)
# 155 3.0 155 110 45
# 155 110 103 (103, 5)
# ############################################################3
# sample_42
# original_samples2/trip42_out.txt (160, 5)
# 160 6.0 160 132 28
# 160 132 133 (132, 5)
# ############################################################3
# sample_43
# original_samples2/trip43_out.txt (70, 5)
# 131 2.0 131 70 61
# 131 70 65 (65, 5)
# ############################################################3
# sample_44
# original_samples2/trip44_out.txt (137, 5)
# 137 2.0 137 69 68
# 137 69 68 (68, 5)
# ############################################################3
# sample_45
# original_samples2/trip45_out.txt (104, 5)
# 112 14.0 112 104 8
# 112 104 104 (104, 5)
# ############################################################3
# sample_46
# original_samples2/trip46_out.txt (86, 5)
# 91 18.0 91 86 5
# 91 86 85 (85, 5)
# ############################################################3
# sample_47
# original_samples2/trip47_out.txt (104, 5)
# 104 4.0 104 75 29
# 104 75 76 (75, 5)
# ############################################################3
# sample_48
# original_samples2/trip48_out.txt (82, 5)
# 82 5.0 82 65 17
# 82 65 65 (65, 5)
# ############################################################3
# sample_49
# original_samples2/trip49_out.txt (153, 5)
# 153 2.0 153 71 82
# 153 71 72 (71, 5)
# ############################################################3
# sample_50
# original_samples2/trip50_out.txt (100, 5)
# 126 5.0 126 100 26
# 126 100 100 (100, 5)
# ############################################################3
# sample_51
# original_samples2/trip51_out.txt (112, 5)
# 112 4.0 112 87 25
# 112 87 84 (84, 5)
# ############################################################3
# sample_52
# original_samples2/trip52_out.txt (205, 5)
# 205 2.0 205 94 111
# 205 94 95 (94, 5)
# ############################################################3
# sample_53
# original_samples2/trip53_out.txt (103, 5)
# 175 2.0 175 103 72
# 175 103 87 (87, 5)
# ############################################################3
# sample_54
# original_samples2/trip54_out.txt (123, 5)
# 123 3.0 123 83 40
# 123 83 82 (82, 5)
# ############################################################3
# sample_55
# original_samples2/trip55_out.txt (92, 5)
# 100 12.0 100 92 8
# 100 92 91 (91, 5)
# ############################################################3
# sample_56
# original_samples2/trip56_out.txt (121, 5)
# 121 3.0 121 83 38
# 121 83 80 (80, 5)
# ############################################################3
# sample_57
# original_samples2/trip57_out.txt (42, 5)
# 90 2.0 90 42 48
# 90 42 43 (42, 5)
# ############################################################3
# sample_58
# original_samples2/trip58_out.txt (118, 5)
# 118 2.0 118 44 74
# 118 44 45 (44, 5)
# ############################################################3
# sample_59
# original_samples2/trip59_out.txt (64, 5)
# 87 4.0 87 64 23
# 87 64 65 (64, 5)
# ############################################################3
# sample_60
# original_samples2/trip60_out.txt (68, 5)
# 68 11.0 68 62 6
# 68 62 61 (61, 5)
# ############################################################3
# sample_61
# original_samples2/trip61_out.txt (45, 5)
# 61 4.0 61 45 16
# 61 45 45 (45, 5)
# ############################################################3
# sample_62
# original_samples2/trip62_out.txt (114, 5)
# 114 2.0 114 47 67
# 114 47 48 (47, 5)
# ############################################################3
# sample_63
# original_samples2/trip63_out.txt (87, 5)
# 94 13.0 94 87 7
# 94 87 86 (86, 5)
# ############################################################3
# sample_64
# original_samples2/trip64_out.txt (48, 5)
# 79 3.0 79 48 31
# 79 48 49 (48, 5)
# ############################################################3
# sample_65
# original_samples2/trip65_out.txt (298, 5)
# 298 1.0 298 40 258
# 298 40 0 (0,)
# ############################################################3
# sample_66
# original_samples2/trip66_out.txt (82, 5)
# 237 2.0 237 82 155
# 237 82 83 (82, 5)
# ############################################################3
# sample_67
# original_samples2/trip67_out.txt (108, 5)
# 108 3.0 108 71 37
# 108 71 72 (71, 5)
# ############################################################3
# sample_68
# original_samples2/trip68_out.txt (60, 5)
# 82 4.0 82 60 22
# 82 60 61 (60, 5)
# ############################################################3
# sample_69
# original_samples2/trip69_out.txt (124, 5)
# 124 2.0 124 57 67
# 124 57 58 (57, 5)
# ############################################################3
# sample_70
# original_samples2/trip70_out.txt (103, 5)
# 103 21.0 103 98 5
# 103 98 98 (98, 5)
# ############################################################3
# sample_71
# original_samples2/trip71_out.txt (134, 5)
# 134 3.0 134 94 40
# 134 94 89 (89, 5)
# ############################################################3
# sample_72
# original_samples2/trip72_out.txt (164, 5)
# 164 3.0 164 116 48
# 164 116 109 (109, 5)
# ############################################################3
# sample_73
# original_samples2/trip73_out.txt (207, 5)
# 207 2.0 207 119 88
# 207 119 103 (103, 5)
# ############################################################3
# sample_74
# original_samples2/trip74_out.txt (93, 5)
# 157 2.0 157 93 64
# 157 93 78 (78, 5)
# ############################################################3
# sample_75
# original_samples2/trip75_out.txt (80, 5)
# 84 21.0 84 80 4
# 84 80 80 (80, 5)
# ############################################################3
# sample_76
# original_samples2/trip76_out.txt (59, 5)
# 62 21.0 62 59 3
# 62 59 59 (59, 5)
# ############################################################3
# sample_77
# original_samples2/trip77_out.txt (88, 5)
# 88 2.0 88 52 36
# 88 52 44 (44, 5)
# ############################################################3
# sample_78
# original_samples2/trip78_out.txt (133, 5)
# 133 1.0 133 40 93
# 133 40 0 (0,)
# ############################################################3
# sample_79
# original_samples2/trip79_out.txt (81, 5)
# 113 4.0 113 81 32
# 113 81 82 (81, 5)
# ############################################################3
# sample_80
# original_samples2/trip80_out.txt (113, 5)
# 113 3.0 113 75 38
# 113 75 75 (75, 5)
# ############################################################3
# sample_81
# original_samples2/trip81_out.txt (115, 5)
# 115 5.0 115 91 24
# 115 91 92 (91, 5)
# ############################################################3
# sample_82
# original_samples2/trip82_out.txt (80, 5)
# 101 5.0 101 80 21
# 101 80 80 (80, 5)
# ############################################################3
# sample_83
# original_samples2/trip83_out.txt (138, 5)
# 138 2.0 138 73 65
# 138 73 69 (69, 5)
# ############################################################3
# sample_84
# original_samples2/trip84_out.txt (91, 5)
# 109 6.0 109 91 18
# 109 91 90 (90, 5)
# ############################################################3
# sample_85
# original_samples2/trip85_out.txt (180, 5)
# 180 2.0 180 80 100
# 180 80 81 (80, 5)
# ############################################################3
# sample_86
# original_samples2/trip86_out.txt (146, 5)
# 149 50.0 149 146 3
# 149 146 146 (146, 5)
# ############################################################3
# sample_87
# original_samples2/trip87_out.txt (108, 5)
# 121 9.0 121 108 13
# 121 108 107 (107, 5)
# ############################################################3
# sample_88
# original_samples2/trip88_out.txt (58, 5)
# 90 3.0 90 58 32
# 90 58 59 (58, 5)
# ############################################################3
# sample_89
# original_samples2/trip89_out.txt (190, 5)
# 190 1.0 190 59 131
# 190 59 0 (0,)
# ############################################################3
# sample_90
# original_samples2/trip90_out.txt (119, 5)
# 156 4.0 156 119 37
# 156 119 117 (117, 5)
# ############################################################3
# sample_91
# original_samples2/trip91_out.txt (165, 5)
# 165 3.0 165 103 62
# 165 103 104 (103, 5)
# ############################################################3
# sample_92
# original_samples2/trip92_out.txt (143, 5)
# 143 11.0 143 130 13
# 143 130 130 (130, 5)
# ############################################################3
# sample_93
# original_samples2/trip93_out.txt (58, 5)
# 121 2.0 121 58 63
# 121 58 59 (58, 5)
# ############################################################3
# sample_94
# original_samples2/trip94_out.txt (109, 5)
# 109 2.0 109 53 56
# 109 53 54 (53, 5)
# ############################################################3
# sample_95
# original_samples2/trip95_out.txt (148, 5)
# 148 3.0 148 94 54
# 148 94 95 (94, 5)
# ############################################################3
# sample_96
# original_samples2/trip96_out.txt (134, 5)
# 134 5.0 134 106 28
# 134 106 107 (106, 5)
# ############################################################3
# sample_97
# original_samples2/trip97_out.txt (114, 5)
# 114 2.0 114 63 51
# 114 63 57 (57, 5)
# ############################################################3
# sample_98
# original_samples2/trip98_out.txt (163, 5)
# 163 2.0 163 85 78
# 163 85 81 (81, 5)
# ############################################################3
# sample_99
# original_samples2/trip99_out.txt (102, 5)
# 128 5.0 128 102 26
# 128 102 102 (102, 5)
# ############################################################3
# sample_100
# original_samples2/trip100_out.txt (130, 5)
# 130 2.0 130 77 53
# 130 77 65 (65, 5)
# ############################################################3
# sample_101
# original_samples2/trip101_out.txt (74, 5)
# 108 3.0 108 74 34
# 108 74 72 (72, 5)
# ############################################################3
# sample_102
# original_samples2/trip102_out.txt (93, 5)
# 93 3.0 93 63 30
# 93 63 62 (62, 5)
# ############################################################3
# sample_103
# original_samples2/trip103_out.txt (62, 5)
# 80 4.0 80 62 18
# 80 62 60 (60, 5)
# ############################################################3
# sample_104
# original_samples2/trip104_out.txt (115, 5)
# 115 2.0 115 52 63
# 115 52 53 (52, 5)
# ############################################################3
# sample_105
# original_samples2/trip105_out.txt (184, 5)
# 184 2.0 184 101 83
# 184 101 92 (92, 5)
# ############################################################3
# sample_106
# original_samples2/trip106_out.txt (182, 5)
# 182 6.0 182 151 31
# 182 151 151 (151, 5)
# ############################################################3
# sample_107
# original_samples2/trip107_out.txt (126, 5)
# 143 8.0 143 126 17
# 143 126 125 (125, 5)
# ############################################################3
# sample_108
# original_samples2/trip108_out.txt (140, 5)
# 140 4.0 140 103 37
# 140 103 104 (103, 5)
# ############################################################3
# sample_109
# original_samples2/trip109_out.txt (202, 5)
# 202 2.0 202 83 119
# 202 83 84 (83, 5)
# ############################################################3
# sample_110
# original_samples2/trip110_out.txt (216, 5)
# 216 3.0 216 154 62
# 216 154 144 (144, 5)
# ############################################################3
# sample_111
# original_samples2/trip111_out.txt (179, 5)
# 179 8.0 179 157 22
# 179 157 156 (156, 5)
# ############################################################3
# sample_112
# original_samples2/trip112_out.txt (178, 5)
# 178 5.0 178 140 38
# 178 140 141 (140, 5)

# %%
ur = 17

for i in range(1):
    videofile = "dataset_samples_callibrated/user"+str(ur)+"/driver_view/sample_" +str(i+1)+".avi"
    vid  = cv2.VideoCapture(videofile)
    if(os.path.exists(videofile)):
        print('y')
    else:
        print('n')
    while(True):
        ret, frame = vid.read()
        if(ret == False):
            break
        n =100
        x,y,w,h = detect_face(frame, 100)
        x1 = x-n; y1= y-n
        if(x1 <=0):
            x1 =0
        if(y1 <= 0):
            y1 = 0
        cv2.rectangle(frame, (x1, y1), (x + w+n, y + h+n), (255, 255, 255), 6)
        frame1 = frame[ y1:y+h+n, x1:x+w+n]
        plt.imshow(frame)
        plt.show()
        break
# Out:
# y

# %%
def crop_driver_video(videofile, destination_video,destination_file, n):
    
    vid  = cv2.VideoCapture(videofile)
    i  =0; flag =0; arr = []
    if(os.path.exists(videofile)):
        
        while(True):
            temp = []
            ret, frame = vid.read()
            if(ret == False):
                flag =1
                break

            if(i ==0):
                x,y,w,h = detect_face(frame, n)
                x1 = x-n; y1= y-n
                if(x1 <=0):
                    x1 =0
                if(y1 <= 0):
                    y1 = 0
                
                fourcc = cv2.VideoWriter_fourcc(*'XVID')
                out = cv2.VideoWriter(destination_video,fourcc, 21, (x+w+n-x1,y+h+n-y1))

                

                #cv2.rectangle(frame, (x1, y1), (x + w+n, y + h+n), (255, 255, 255), 6)
        
            frame1 = frame[y1:y+h+n, x1:x+w+n]
            temp.append(y1)
            temp.append(y+h+n)
            temp.append(x1)
            temp.append(x+w+n)
            arr.append(temp)
            #print(frame1.shape)
            #print(frame.shape, frame1.shape)
            #print(i, w+2*n,h+2*n)
          #  cv2.rectangle(image, (x-n, y-n), (x + w+n, y + h+n), (255, 255, 255), 6)
            out.write(frame1)
            i +=1
        np.save(destination_file, np.array(arr))
        if(flag ==0):
            out.release()
            vid.release()
            
        else:
            print(i)

# %%
def call_crop_driver_video(ur):
    directory1 = "dataset_samples_callibrated/user"+str(ur)+"/driver_view_cropped2/"
    directory2 = "dataset_samples_callibrated/user"+str(ur)+"/explicit_face_points/"
    if not os.path.exists(directory1):
        os.makedirs(directory1)
    
    if not os.path.exists(directory2):
        os.makedirs(directory2)
        
    for i in range(0,112):
        print("user"+str(ur), "sample_" +str(i+1)+".avi")
        video_filename = "dataset_samples_callibrated/user"+str(ur)+"/driver_view/sample_" +str(i+1)+".avi"
        crop_driver_video(video_filename, directory1 +"sample_" + str(i+1)+".avi", directory2 +"sample_" + str(i+1)+"_face_points.npy",100)

# %%
call_crop_driver_video(19)
# Out:
# user19 sample_1.avi
# 99
# user19 sample_2.avi
# 100
# user19 sample_3.avi
# 100
# user19 sample_4.avi
# 100
# user19 sample_5.avi
# 100
# user19 sample_6.avi
# 100
# user19 sample_7.avi
# 99
# user19 sample_8.avi
# 100
# user19 sample_9.avi
# 99
# user19 sample_10.avi
# 64
# user19 sample_11.avi
# 112
# user19 sample_12.avi
# 80
# user19 sample_13.avi
# 89
# user19 sample_14.avi
# 75
# user19 sample_15.avi
# 97
# user19 sample_16.avi
# 76
# user19 sample_17.avi
# 69
# user19 sample_18.avi
# 86
# user19 sample_19.avi
# 49
# user19 sample_20.avi
# 144
# user19 sample_21.avi
# 129
# user19 sample_22.avi
# 111
# user19 sample_23.avi
# 75
# user19 sample_24.avi
# 130
# user19 sample_25.avi
# 138
# user19 sample_26.avi
# 141
# user19 sample_27.avi
# 146
# user19 sample_28.avi
# 87
# user19 sample_29.avi
# 112
# user19 sample_30.avi
# 76
# user19 sample_31.avi
# 60
# user19 sample_32.avi
# 75
# user19 sample_33.avi
# 90
# user19 sample_34.avi
# 129
# user19 sample_35.avi
# 107
# user19 sample_36.avi
# 125
# user19 sample_37.avi
# 94
# user19 sample_38.avi
# 164
