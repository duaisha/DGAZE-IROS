# %%
import pandas as pd
import numpy as np
import cv2
import os
from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2
import matplotlib.pyplot as plt

# %%
def detect_face(img, n):
    
    # initialize dlib's face detector (HOG-based) and then create
    # the facial landmark predictor
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("shape_predictor.dat")
    
    # load the input image, resize it, and convert it to grayscale
    #image = cv2.imread(img)
    image = img
#     image = imutils.resize(image, width=500)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # detect faces in the grayscale image
    rects = detector(gray, 1)
        
    # loop over the face detections
    for (i, rect) in enumerate(rects):
        print(i)
        # determine the facial landmarks for the face region, then
        # convert the facial landmark (x, y)-coordinates to a NumPy
        # array
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)

        # convert dlib's rectangle to a OpenCV-style bounding box
        # [i.e., (x, y, w, h)], then draw the face bounding box
        (x, y, w, h) = face_utils.rect_to_bb(rect)
#         cv2.rectangle(image, (x-n, y-n), (x + w+n, y + h+n), (255, 255, 255), 6)

#         # show the face number
# #         cv2.putText(image, "Face #{}".format(i + 1), (x - 10, y - 10),
# #             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#         # loop over the (x, y)-coordinates for the facial landmarks
#         # and draw them on the image
#         for (x, y) in shape:
#             cv2.circle(image, (x, y), 4, (255, 255, 255), -1)
            
        
#         plt.imshow(image)
#         plt.show()
        return x,y,w,h

# %%
def count_frames(video):
    count = 0
    vid = cv2.VideoCapture(video)    
    while(True):
        ret, frame = vid.read()
        if(ret == False):
            break
        count += 1
        
    return count

# %%
def callibrate_corresponding_videos(video1, video2, video3, textfile, output_vid1, output_vid2, output_vid3, 
                                    out_textfile, n1):
    
    print("############################################################3")
    print("sample_" +str(n1))
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    
    if(n1>=10):
        file1 = pd.read_csv(textfile, header = None).values
        print(textfile,file1.shape)
    else:
        file1 = np.load(textfile)
        print(textfile,file1.shape)
    
    arr = [];
    
    #################################################################################################
    out1 = cv2.VideoWriter(output_vid1, fourcc, 25, (1440,1080)) ### driver
    out2 = cv2.VideoWriter(output_vid2, fourcc, 25, (1440,1080)) ### road
    out3 = cv2.VideoWriter(output_vid3, fourcc, 25, (1920, 1080)) ### original
    
    #################################################################################################
    cap1 = cv2.VideoCapture(video1)###### driver ###################
    frame_count1 = count_frames(video1)
    
    cap2 = cv2.VideoCapture(video2)###### road ####################
    frame_count2 = count_frames(video2)
    
    cap3 = cv2.VideoCapture(video3)###### Original ####################
    frame_count3 = count_frames(video3)
    
    #print(frame_count1, frame_count2, frame_count3)

    #################################################################################################
    i = 0; count = 0; flag =0

    if(frame_count2 == frame_count3):
        flag =1
        n = frame_count2
        first = frame_count2
        second = frame_count3

    elif(frame_count3 < frame_count2):
        n = frame_count2
        first = frame_count2
        second = frame_count3

    elif(frame_count3 > frame_count2):
        n = frame_count3
        first = frame_count3
        second = frame_count2

    diff = first - second
    if(diff != 0):
        drop = np.round(first/diff)
        print(n, drop, first, second, diff)
    k =0
    #print(file1)
    while(i < n):
        if(flag == 0):
            if(diff != 0 and i%drop == 0 ):
               # print(i)
                if(frame_count2 > frame_count3):
                    ret2, frame2 = cap2.read()
                    ret1, frame1 = cap1.read()

                else:
                    ret3, frame3 = cap3.read()
                   # print(i)
                    k +=1
            else:
                count += 1
               # print(k)
                ret1, frame1 = cap1.read()
                ret2, frame2 = cap2.read()
                ret3, frame3 = cap3.read()
                if(ret2 == False or ret3 == False):
                    break
                arr.append(file1[k])
                k +=1

                #print(frame1.shape, frame2.shape, frame3.shape)
              #  frame2 = cv2.resize(frame2, (692, 460))
              #  print(frame1.shape, frame2.shape)
                #print(ret1, ret2)
    #             if(ret2 == False or ret3 == False):
    #                 break
             #   frame3 = np.concatenate((frame1, frame2), axis =1)
                out1.write(frame1)
                out2.write(frame2)
                out3.write(frame3)

            i += 1
            
        elif(flag ==1):
            count += 1
            ret1, frame1 = cap1.read()
            ret2, frame2 = cap2.read()
            ret3, frame3 = cap3.read()
            if(ret2 == False or ret3 == False):
                break
            arr.append(file1[k])
            k +=1

            out1.write(frame1)
            out2.write(frame2)
            out3.write(frame3)

            i += 1
        
    print(first, second, count, np.array(arr).shape)
    
    arr = np.array(arr)
    np.save(out_textfile, arr)
        
    out1.release(); out2.release(); out3.release()
    cap1.release(); cap2.release(); cap3.release()

# %%
def call_callibrate_corresponding_videos(ur):

    directory1 = "dataset_samples_callibrated/user"+str(ur)
    if not os.path.exists(directory1):
        os.makedirs(directory1)
        
    directory2 = "dataset_samples_callibrated/user"+str(ur)+"/driver_view"
    if not os.path.exists(directory2):
        os.makedirs(directory2)
        
    directory3 = "dataset_samples_callibrated/user"+str(ur)+"/road_view"
    if not os.path.exists(directory3):
        os.makedirs(directory3)
        
    directory4 = "dataset_samples_callibrated/user"+str(ur)+"/original_road_view"
    if not os.path.exists(directory4):
        os.makedirs(directory4)
        
    for i in range(0,112):
  
        video1 = "dataset_samples/user"+str(ur)+"/driver_view/sample"+str(i+1)+".avi"            
        video2 = "dataset_samples/user"+str(ur)+"/road_view/sample"+str(i+1)+".avi"
        video3 = "original_samples2/trip"+str(i+1)+"_out_hist.avi"

        if(i+1 < 10):
            textfile = "original_samples2/trip"+str(i+1)+"_out.npy"
        else:
            textfile = "original_samples2/trip"+str(i+1)+"_out.txt"


        out_video1 = directory2 + "/sample_"+str(i+1)+".avi"
        out_video2 = directory3 + "/sample_"+str(i+1)+".avi"
        out_video3 = directory4 + "/sample_"+str(i+1)+".avi"
        out_textfile = directory4 + "/sample_"+str(i+1)+".npy"

        callibrate_corresponding_videos(video1, video2, video3, textfile, out_video1, out_video2, out_video3, out_textfile, i+1)

# %%
# call_callibrate_corresponding_videos(2)

# %%
call_callibrate_corresponding_videos(24)
# Out:
# ############################################################3
# sample_1
# original_samples2/trip1_out.npy (100, 2)
# 110 11.0 110 100 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-bef841abebbf> in <module>()
# ----> 1 call_callibrate_corresponding_videos(24)
#
# <ipython-input-5-166ceaa6c992> in call_callibrate_corresponding_videos(ur)
#      34         out_textfile = directory4 + "/sample_"+str(i+1)+".npy"
#      35
# ---> 36         callibrate_corresponding_videos(video1, video2, video3, textfile, out_video1, out_video2, out_video3, out_textfile, i+1)
#
# <ipython-input-4-7518eeb56f99> in callibrate_corresponding_videos(video1, video2, video3, textfile, output_vid1, output_vid2, output_vid3, out_textfile, n1)
#      89     #                 break
#      90              #   frame3 = np.concatenate((frame1, frame2), axis =1)
# ---> 91                 out1.write(frame1)
#      92                 out2.write(frame2)
#      93                 out3.write(frame3)
#
# KeyboardInterrupt:

# %%
ur = 16

for i in range(1):
    videofile = "dataset_samples_callibrated/user"+str(ur)+"/driver_view/sample_79.avi"
    vid  = cv2.VideoCapture(videofile)
    if(os.path.exists(videofile)):
        print('y')
    else:
        print('n')
    while(True):
        ret, frame = vid.read()
        print(ret)
        if(ret == False):
            break
        n =100
        x,y,w,h = detect_face(frame, 100)
        x1 = x-n; y1= y-n
        if(x1 <=0):
            x1 =0
        if(y1 <= 0):
            y1 = 0
        cv2.rectangle(frame, (x1, y1), (x + w+n, y + h+n), (255, 255, 255), 6)
        frame1 = frame[ y1:y+h+n, x1:x+w+n]
        plt.imshow(frame)
        plt.show()
        break
# Out:
# y
# True

# %%
def crop_driver_video(videofile, destination_video,destination_file, n):
    
    vid  = cv2.VideoCapture(videofile)
    i  =0; flag =0; arr = []
    if(os.path.exists(videofile)):
        
        while(True):
            temp = []
            ret, frame = vid.read()
            if(ret == False):
                flag =1
                break

            if(i ==0):
                x,y,w,h = detect_face(frame, n)
                x1 = x-n; y1= y-n
                if(x1 <=0):
                    x1 =0
                if(y1 <= 0):
                    y1 = 0
                
                fourcc = cv2.VideoWriter_fourcc(*'XVID')
                out = cv2.VideoWriter(destination_video,fourcc, 21, (x+w+n-x1,y+h+n-y1))

                

                #cv2.rectangle(frame, (x1, y1), (x + w+n, y + h+n), (255, 255, 255), 6)
        
            frame1 = frame[y1:y+h+n, x1:x+w+n]
            temp.append(y1)
            temp.append(y+h+n)
            temp.append(x1)
            temp.append(x+w+n)
            arr.append(temp)
            #print(frame1.shape)
            #print(frame.shape, frame1.shape)
            #print(i, w+2*n,h+2*n)
          #  cv2.rectangle(image, (x-n, y-n), (x + w+n, y + h+n), (255, 255, 255), 6)
            out.write(frame1)
            i +=1
        np.save(destination_file, np.array(arr))
        if(flag ==0):
            out.release()
            vid.release()
            
        else:
            print(i)

# %%
def call_crop_driver_video(ur):
    directory1 = "dataset_samples_callibrated/user"+str(ur)+"/driver_view_cropped2/"
    directory2 = "dataset_samples_callibrated/user"+str(ur)+"/explicit_face_points/"
    if not os.path.exists(directory1):
        os.makedirs(directory1)
    
    if not os.path.exists(directory2):
        os.makedirs(directory2)
        
    for i in range(0,112):
        print("user"+str(ur), "sample_" +str(i+1)+".avi")
        video_filename = "dataset_samples_callibrated/user"+str(ur)+"/driver_view/sample_" +str(i+1)+".avi"
        crop_driver_video(video_filename, directory1 +"sample_" + str(i+1)+".avi", directory2 +"sample_" + str(i+1)+"_face_points.npy",100)

# %%
call_crop_driver_video(18)
# Out:
# user18 sample_1.avi
# 0
# 99
# user18 sample_2.avi
# 0
# 99
# user18 sample_3.avi
# 0
# 99
# user18 sample_4.avi
# 0
# 99
# user18 sample_5.avi
# 0
# 100
# user18 sample_6.avi
# 0
# 99
# user18 sample_7.avi
# 0
# 100
# user18 sample_8.avi
# 0
# 100
# user18 sample_9.avi
# 0
# 100
# user18 sample_10.avi
# 0
# 64
# user18 sample_11.avi
# 0
# 112
# user18 sample_12.avi
# 0
# 81
# user18 sample_13.avi
# 0
# 84
# user18 sample_14.avi
# 0
# 75
# user18 sample_15.avi
# 0
# 97
# user18 sample_16.avi
# 0
# 80
# user18 sample_17.avi
# 0
# 70
# user18 sample_18.avi
# 0
# 82
# user18 sample_19.avi
# 0
# 49
# user18 sample_20.avi
# 0
# 147
# user18 sample_21.avi
# 0
# 129
# user18 sample_22.avi
# 0
# 115
# user18 sample_23.avi
# 0
# 78
# user18 sample_24.avi
# 0
# 131
# user18 sample_25.avi
# 0
# 135
# user18 sample_26.avi
# 0
# 141
# user18 sample_27.avi
# 0
# 148
# user18 sample_28.avi
# 0
# 91
# user18 sample_29.avi
# 0
# 110
# user18 sample_30.avi
# 0
# 72
# user18 sample_31.avi
# 0
# 62
# user18 sample_32.avi
# 0
# 75
# user18 sample_33.avi
# 0
# 91
# user18 sample_34.avi
# 0
# 127
# user18 sample_35.avi
# 0
# 106
# user18 sample_36.avi
# 0
# 125
# user18 sample_37.avi
# 0
# 94
# user18 sample_38.avi
# 0
# 165
# user18 sample_39.avi
# 0
# 140
# user18 sample_40.avi
# 0
# 122
# user18 sample_41.avi
# 0
# 152
# user18 sample_42.avi
# 0
# 156
# user18 sample_43.avi
# 0
# 67
# user18 sample_44.avi
# 0
# 137
# user18 sample_45.avi
# 0
# 102
# user18 sample_46.avi
# 0
# 86
# user18 sample_47.avi
# 0
# 100
# user18 sample_48.avi
# 0
# 82
# user18 sample_49.avi
# 0
# 151
# user18 sample_50.avi
# 0
# 99
# user18 sample_51.avi
# 0
# 109
# user18 sample_52.avi
# 0
# 202
# user18 sample_53.avi
# 0
# 100
# user18 sample_54.avi
# 0
# 121
# user18 sample_55.avi
# 0
# 92
# user18 sample_56.avi
# 0
# 118
# user18 sample_57.avi
# 0
# 42
# user18 sample_58.avi
# 0
# 114
# user18 sample_59.avi
# 0
# 60
# user18 sample_60.avi
# 0
# 68
# user18 sample_61.avi
# 0
# 45
# user18 sample_62.avi
# 0
# 112
# user18 sample_63.avi
# 0
# 87
# user18 sample_64.avi
# 0
# 48
# user18 sample_65.avi
# 0
# 297
# user18 sample_66.avi
# 0
# 82
# user18 sample_67.avi
# 0
# 106
# user18 sample_68.avi
# 0
# 60
# user18 sample_69.avi
# 0
# 124
# user18 sample_70.avi
# 0
# 103
# user18 sample_71.avi
# 0
# 134
# user18 sample_72.avi
# 0
# 161
# user18 sample_73.avi
# 0
# 207
# user18 sample_74.avi
# 0
# 91
# user18 sample_75.avi
# 0
# 80
# user18 sample_76.avi
# 0
# 29
# user18 sample_77.avi
# 0
# 88
# user18 sample_78.avi
# 0
# 131
# user18 sample_79.avi
# 0
# 81
# user18 sample_80.avi
# 0
# 109
# user18 sample_81.avi
# 0
# 111
# user18 sample_82.avi
# 0
# 80
# user18 sample_83.avi
# 0
# 127
# user18 sample_84.avi
# 0
# 91
# user18 sample_85.avi
# 0
# 180
# user18 sample_86.avi
# 0
# 146
# user18 sample_87.avi
# 0
# 105
# user18 sample_88.avi
# 0
# 56
# user18 sample_89.avi
# 0
# 188
# user18 sample_90.avi
# 0
# 114
# user18 sample_91.avi
# 0
# 165
# user18 sample_92.avi
# 0
# 143
# user18 sample_93.avi
# 0
# 58
# user18 sample_94.avi
# 0
# 109
# user18 sample_95.avi
# 0
# 145
# user18 sample_96.avi
# 0
# 99
# user18 sample_97.avi
# 0
# 110
# user18 sample_98.avi
# 0
# 162
# user18 sample_99.avi
# 0
# 100
# user18 sample_100.avi
# 0
# 130
# user18 sample_101.avi
# 0
# 74
# user18 sample_102.avi
# 0
# 90
# user18 sample_103.avi
# 0
# 62
# user18 sample_104.avi
# 0
# 111
# user18 sample_105.avi
# 0
# 182
# user18 sample_106.avi
# 0
# 182
# user18 sample_107.avi
# 0
# 123
# user18 sample_108.avi
# 0
# 135
# user18 sample_109.avi
# 0
# 202
# user18 sample_110.avi
# 0
# 216
# user18 sample_111.avi
# 0
# 178
# user18 sample_112.avi
# 0
# 64

# %%
call_crop_driver_video(22)
# Out:
# user22 sample_1.avi
# 0
# 99
# user22 sample_2.avi
# 0
# 100
# user22 sample_3.avi
# 0
# 100
# user22 sample_4.avi
# 0
# 75
# user22 sample_5.avi
# 0
# 99
# user22 sample_6.avi
# 0
# 99
# user22 sample_7.avi
# 0
# 99
# user22 sample_8.avi
# 0
# 99
# user22 sample_9.avi
# 0
# 99
# user22 sample_10.avi
# 0
# 64
# user22 sample_11.avi
# 0
# 112
# user22 sample_12.avi
# 0
# 80
# user22 sample_13.avi
# 0
# 86
# user22 sample_14.avi
# 0
# 74
# user22 sample_15.avi
# 0
# 97
# user22 sample_16.avi
# 0
# 80
# user22 sample_17.avi
# 0
# 68
# user22 sample_18.avi
# 0
# 80
# user22 sample_19.avi
# 0
# 49
# user22 sample_20.avi
# 0
# 146
# user22 sample_21.avi
# 0
# 133
# user22 sample_22.avi
# 0
# 115
# user22 sample_23.avi
# 0
# 79
# user22 sample_24.avi
# 0
# 133
# user22 sample_25.avi
# 0
# 135
# user22 sample_26.avi
# 0
# 139
# user22 sample_27.avi
# 0
# 144
# user22 sample_28.avi
# 0
# 91
# user22 sample_29.avi
# 0
# 112
# user22 sample_30.avi
# 0
# 74
# user22 sample_31.avi
# 0
# 62
# user22 sample_32.avi
# 0
# 73
# user22 sample_33.avi
# 0
# 85
# user22 sample_34.avi
# 0
# 129
# user22 sample_35.avi
# 0
# 107
# user22 sample_36.avi
# 0
# 125
# user22 sample_37.avi
# 0
# 89
# user22 sample_38.avi
# 0
# 161
# user22 sample_39.avi
# 0
# 138
# user22 sample_40.avi
# 0
# 122
# user22 sample_41.avi
# 0
# 150
# user22 sample_42.avi
# 0
# 159
# user22 sample_43.avi
# 0
# 68
# user22 sample_44.avi
# 0
# 137
# user22 sample_45.avi
# 0
# 104
# user22 sample_46.avi
# 0
# 86
# user22 sample_47.avi
# 0
# 104
# user22 sample_48.avi
# 0
# 79
# user22 sample_49.avi
# 0
# 153
# user22 sample_50.avi
# 0
# 100
# user22 sample_51.avi
# 0
# 112
# user22 sample_52.avi
# 0
# 205
# user22 sample_53.avi
# 0
# 103
# user22 sample_54.avi
# 0
# 123
# user22 sample_55.avi
# 0
# 86
# user22 sample_56.avi
# 0
# 121
# user22 sample_57.avi
# 0
# 35
# user22 sample_58.avi
# 0
# 118
# user22 sample_59.avi
# 0
# 64
# user22 sample_60.avi
# 0
# 68
# user22 sample_61.avi
# 0
# 45
# user22 sample_62.avi
# 0
# 114
# user22 sample_63.avi
# 0
# 81
# user22 sample_64.avi
# 0
# 40
# user22 sample_65.avi
# 0
# 293
# user22 sample_66.avi
# 0
# 78
# user22 sample_67.avi
# 0
# 108
# user22 sample_68.avi
# 0
# 60
# user22 sample_69.avi
# 0
# 124
# user22 sample_70.avi
# 0
# 103
# user22 sample_71.avi
# 0
# 134
# user22 sample_72.avi
# 0
# 164
# user22 sample_73.avi
# 0
# 207
# user22 sample_74.avi
# 0
# 88
# user22 sample_75.avi
# 0
# 80
# user22 sample_76.avi
# 0
# 59
# user22 sample_77.avi
# 0
# 84
# user22 sample_78.avi
# 0
# 132
# user22 sample_79.avi
# 0
# 78
# user22 sample_80.avi
# 0
# 113
# user22 sample_81.avi
# 0
# 115
# user22 sample_82.avi
# 0
# 80
# user22 sample_83.avi
# 0
# 48
# user22 sample_84.avi
# 0
# 91
# user22 sample_85.avi
# 0
# 180
# user22 sample_86.avi
# 0
# 146
# user22 sample_87.avi
# 0
# 108
# user22 sample_88.avi
# 0
# 57
# user22 sample_89.avi
# 0
# 190
# user22 sample_90.avi
# 0
# 116
# user22 sample_91.avi
# 0
# 163
# user22 sample_92.avi
# 0
# 141
# user22 sample_93.avi
# 0
# 58
# user22 sample_94.avi
# 0
# 105
# user22 sample_95.avi
# 0
# 148
# user22 sample_96.avi
# 0
# 134
# user22 sample_97.avi
# 0
# 110
# user22 sample_98.avi
# 0
# 163
# user22 sample_99.avi
# 0
# 102
# user22 sample_100.avi
# 0
# 129
# user22 sample_101.avi
# 0
# 73
# user22 sample_102.avi
# 0
# 89
# user22 sample_103.avi
# 0
# 58
# user22 sample_104.avi
# 0
# 111
# user22 sample_105.avi
# 0
# 184
# user22 sample_106.avi
# 0
# 182
# user22 sample_107.avi
# 0
# 125
# user22 sample_108.avi
# 0
# 140
# user22 sample_109.avi
# 0
# 202
# user22 sample_110.avi
# 0
# 216
# user22 sample_111.avi
# 0
# 179
# user22 sample_112.avi
# 0
# 60
